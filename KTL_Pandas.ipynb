# %% [markdown]
# <a href="https://colab.research.google.com/github/g9772690/KTL_Lecture/blob/main/KTL_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas
#
# *  pandas 라이브러리는 데이타 분석을 위해 널리 사용되는 파이썬 라이브러리 패키지로써 사용하기 쉬운 고성능 데이터 구조와 데이터 분석 도구를 제공한다.
# *  주 데이터 구조는 `DataFrame`으로 2D 테이블로 생각할 수 있다(열 이름과 행 레이블이 있는 스프레드시트와 비슷하다).
# *  엑셀에 있는 많은 기능을 프로그램에서 사용할 수 있다. 여기에는 피봇 테이블이나 다른 열을 기반으로 열을 계산하고 그래프 출력하는 기능 등이 포함된다.
# *  열 값으로 행을 그룹핑할 수도 있다. 또한 SQL과 비슷하게 테이블을 조인할 수 있다. 판다스는 시계열 데이터를 다루는데도 뛰어나다.*
# *  pandas를 사용하기 위해서는 먼저 pandas를 import 한다. pandas는 크게 세 가지의 자료구조를 지원하고 있는데, 1차원 자료구조인 Series, 2차원 자료구조인 DataFrame, 그리고 3차원 자료구조인 Panel을 지원한다.
# *  numpy에 비해 pandas는 다른 데이터타입을 담을 수 있는 특징을 가지고 있다.
# - Series 자료형 : 가장 간단한 1차원 자료구조인 Series는 배열/리스트와 같은 일련의 시퀀스 데이터를 받아들이는데, 별도의 인덱스 레이블을 지정하지 않으면 자동적으로 0부터 시작되는 디폴트 정수 인덱스를 사용한다.
# - DataFrame : 복수의 열을 가진 2차원 데이터
#     - 판다스가 잘 하는 일
#       1. 결측 데이터 처리
#       2. 데이터 추가 삭제(새로운 열의 추가, 특정 열의 삭제등)
#       3. 데이터 정렬과 다양한 데이터 조작
#     - 데이터 불러오기 및 저장하기
#       - 파이썬 리스트, 딕셔너리, 넘파이 배열을 데이터 프레임으로 변환할 수 있다.
#       - 판다스로 CSV 파일이나 TSV 파일, 엑셀 파일등을 열 수 있다.
#       - URL을 통해 웹 사이트의 CSV 또는 JSON 과 같은 원격 파일 또는 데이터베이스를 열 수 있다.
#
# *  https://pandas.pydata.org/

# %% [markdown]
#   - 데이터 보기 및 검사
#     - mean()로 모든 열의 평균을 계산할 수 있다.
#     - corr()로 데이터 프레임의 열 사이의 상관 관계를 계산할 수 있다.
#     - count()로 각 데이터 프레임 열에서 null이 아닌 값의 개수를 계산할 수 있다.
#   - 필터, 정렬 및 그룹화
#     - sort_values()로 데이터를 정렬할 수 있다.
#     - 조건을 사용하여 열을 필터링할 수 있다.
#     - groupby()를 이용하여 기준에 따라 몇 개의 그룹으로 데이터를 분할할 수 있다.
#   - 데이터 정제
#     - 데이터의 누락 값을 확인할 수 있다.
#     - 특정한 값을 다른 값으로 대체할 수 있다.

# %% [markdown]
# **CSV**
#   - CSV는 테이블 형식의 데이터를 저장하고 이동하는 데 사용되는 구조화된 텍스트 파일 형식이다.
#   - CSV는 쉼표로 구분한 변수comma separated variables의 약자이다.
#   - CSV의 역사는 1972년으로 거슬러 올라가며 Microsoft Excel와 같은 스프레드 시트spread sheet 소프트웨어에 적합한 형식이다.
#   - 데이터 과학에서 사용되는 데이터 가운데 상당한 비율의 데이터들이 CSV 형식으로 공유되는 경우가 많다.
#   - CSV 파일은 필드를 나타내는 열과 레코드를 나타내는 행으로 구성
#   - 만약 데이터의 중간에 구분자가 포함되어야 한다면 따옴표를 사용하여 필드를 묶어야 함
#     - 예를 들어서 'Gildong, Hong'이라는 데이터가 있다고 하자. 데이터의 중간에 쉼표(,)가 포함되어 있다. 이러한 경우에는 구분자로 사용되는 쉼표와 구분하기 위하여 반드시 데이터를 따옴표로 감싸야 한다.
#   - CSV 파일의 첫 번째 레코드에는 열 제목이 포함되어 있을 수 있다.
#     - CSV 형식 자체의 요구사항이 아니라 단순히 일반적인 관행
#   - CSV 파일의 크기를 알 수 없고 잠재적으로 크기가 큰 경우 한 번에 모든 레코드를 읽지 않는 것이 좋다.
#     - 이때는 현재 행을 읽고, 현재 행을 처리한 후에 삭제하고 다음 행을 가져오는 방식이 필요할 수도 있다. 아니면 특정한 크기만큼의 데이터를 읽어서 처리한 뒤에, 다음으로 또 그만큼의 크기를 가져오는 방식을 사용할 수도 있을 것이다.

# %% [markdown]
# ### pandas 라이브러리 사용

# %%
import pandas as pd

# %% [markdown]
# ### **데이터 구조**
# pandas 라이브러리는 다음과 같은 유용한 데이터 구조를 포함하고 있다.
#
# * Series 객체는 1D 배열입니다. (열 이름과 행 레이블을 가진) 스프레드시트의 열과 비슷하다.
# * DataFrame 객체는 2D 테이블입니다. (열 이름과 행 레이블을 가진) 스프레드시트와 비슷하다.

# %% [markdown]
# ### **Series 객체 생성**

# %%
s=pd.Series([2,-1,5,9])
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Series 객체는 넘파이 ndarray와 비슷하며, 종종 넘파이 함수에 매개변수로 사용된다.

# %%
import numpy as np
a=np.exp(s)
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Series 객체에 대한 산술 연산 가능하며, ndarray와 비슷하게 연산된다.

# %%
s+[100,200,300,400]
# Out:
# 0    102
# 1    199
# 2    305
# 3    409
# dtype: int64

# %% [markdown]
# 넘파이와 비슷하게 Series 에 하나의 숫자를 더하면 Series에 있는 모든 원소에 더해진다. -> 브로드캐스팅(broadcasting)

# %%
s+1000
# Out:
# 0    1002
# 1     999
# 2    1005
# 3    1009
# dtype: int64

# %%
s<0
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %% [markdown]
# ### **INDEX LABEL**
#
# Series 객체에 있는 각 원소는 인덱스 레이블(index label)이라 불리는 고유한 식별자를 가지고 있다. 기본적으로 Series에 있는 원소의 순서이다(`0`에서 시작). 하지만 수동으로 인덱스 레이블을 지정할 수도 있다.

# %%
s2=pd.Series([68,83,112,68],index=['alice','bob','charles','darwin'])
s2
# Out:
# alice       68
# bob         83
# charles    112
# darwin      68
# dtype: int64

# %% [markdown]
# 그다음 딕셔너리와 유사하게 인덱스명으로 인덱싱할 수 있고 일반 배열처럼 정수 인덱스를 사용하여 원소에 접근할 수도 있다

# %%
s2['bob']
# Out:
# 83

# %%
s2[1]
# Out:
# 83

# %% [markdown]
# 레이블이나 정수를 사용해 접근할 때 명확하게 하기 위해 레이블은 **loc** 속성을 사용하고 정수는 **iloc** 속성을 사용하는 것이 좋다

# %%
s2.loc['bob']
# Out:
# 83

# %%
s2.iloc[1]
# Out:
# 83

# %% [markdown]
# Series는 인덱스 레이블을 슬라이싱할 수도 있다

# %%
s2['alice':'charles']
# Out:
# alice       68
# bob         83
# charles    112
# dtype: int64

# %% [markdown]
# 기본 정수 레이블을 사용한 슬라이싱의 경우, 결과에 대한 인덱스값에 유의해야 한다.

# %%
s3=pd.Series([100,101,102,103])
s3
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# dtype: int64

# %% [markdown]
# 아래 슬라이싱 결과에서 인덱스 레이블은 0으로 시작되지 않는다.

# %%
s4=s3[2:]
s4
# Out:
# 2    102
# 3    103
# dtype: int64

# %%
try:
  print(s4[0])
except KeyError as e:
  print('키 에러:',e)
# Out:
# 키 에러: 0

# %% [markdown]
# 하지만 iloc 속성을 사용해 정수 인덱스로 원소에 접근할 수 있다. Series 객체를 사용할 때 loc와 iloc를 사용하는 것이 좋은 이유이다

# %%
s4.iloc[0]
# Out:
# 102

# %% [markdown]
# ### **dictionary 를 통한 Series 객체 생성**
# dict에서 Series 객체를 만들 수 있다. 이때 키는 인덱스 레이블로 사용된다.

# %%
weights={'alice':68, 'bob':83, 'colin':86, 'darwin':68}
s3=pd.Series(weights)
s3
# Out:
# alice     68
# bob       83
# colin     86
# darwin    68
# dtype: int64

# %% [markdown]
# Series에 포함할 원소를 제어하고 index를 지정하여 명시적으로 순서를 결정할 수 있다.

# %%
s4=pd.Series(weights,index=['colin','alice'])
s4
# Out:
# colin    86
# alice    68
# dtype: int64

# %% [markdown]
# ### **자동 정렬**
#
# 여러 개의 Series 객체를 다룰 때 pandas는 자동으로 인덱스 레이블에 따라 원소를 정렬합니다.

# %%
print(s2.keys())
print(s3.keys())
# Out:
# Index(['alice', 'bob', 'charles', 'darwin'], dtype='object')
# Index(['alice', 'bob', 'colin', 'darwin'], dtype='object')

# %%
s2+s3
# Out:
# alice      136.0
# bob        166.0
# charles      NaN
# colin        NaN
# darwin     136.0
# dtype: float64

# %% [markdown]
# 만들어진 Series는 s2와 s3의 인덱스 레이블의 합집합을 담고 있습니다. s2에 "colin"이 없고 s3에 "charles"가 없기 때문에 이 원소는 NaN 값을 가진다.(Not-a-Number는 누락).
#
# 자동 정렬은 구조가 다르고 누락된 값이 있는 여러 데이터를 다룰 때 매우 편리하지만 올바른 인덱스 레이블을 지정하는 것을 잊는다면 원치않는 결과가 나올수도 있다.

# %%
s3=pd.Series([100,101,102,103])
s2+s3
# Out:
# alice     NaN
# bob       NaN
# charles   NaN
# darwin    NaN
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# dtype: float64

# %% [markdown]
# 레이블이 하나도 맞지 않기 때문에 판다스가 이 Series를 정렬할 수 없다. 따라서 모두 NaN이 되었다.

# %% [markdown]
# ### **스칼라로 초기화**
#
# 스칼라와 인덱스 레이블의 리스트로 Series 객체를 초기화할 수도 있다. 모든 원소가 이 스칼라 값으로 설정된다.

# %%
meaning=pd.Series(11,index=list('abcde'))
meaning
# Out:
# a    11
# b    11
# c    11
# d    11
# e    11
# dtype: int64

# %% [markdown]
# ### **Series 객체 이름정의**
#
# `Series`는 `name`을 가질 수 있습니다:

# %%
s5=pd.Series([10,20],index=list('ab'),name='bye')
s5
# Out:
# a    10
# b    20
# Name: bye, dtype: int64

# %% [markdown]
# ### **Series 그래프 출력**
#
# 맷플롯립을 사용해 Series 데이터를 쉽게 그래프로 출력할 수 있다. 맷플롯립을 임포트하고 plot() 메서드를 호출하면 끝

# %%
import matplotlib.pyplot as plt
temperatures=[4.4, 5.1, 6.1, 6.2, 6.1, 6.1, 5.7, 5.2, 4.7, 4.1, 3.9, 3.5]
s7=pd.Series(temperatures, name='Temperatures')
s7.plot()
plt.show()

# %% [markdown]
# ### **date_range() 와 period_range()**
#
# 많은 데이터셋에 타임스탬프가 포함되어 있다. 판다스는 이런 데이터를 다루는데 장점이 있다:
# * (2023 Q3 같은) 기간과 ("monthly" 같은) 빈도를 표현할 수 있다.
# * 기간을 실제 타임스탬프로 변환하거나 그 반대로 변환할 수 있다.
# * 데이터를 리샘플링하고 원하는 방식으로 값을 모을 수 있다.
# * 시간대를 다룰 수 있다.
# * 먼저 pd.date_range()를 사용해 시계열을 만들어 보자. 다음은 2023년 07월 01일 5:30pm에서 시작하여 1시간간격의 12개의 datetime을 가지는 DatetimeIndex를 반환한다.

# %%
dates=pd.date_range('2023/07/01 5:30pm',periods=12, freq='H')
dates
# Out:
# DatetimeIndex(['2023-07-01 17:30:00', '2023-07-01 18:30:00',
#                '2023-07-01 19:30:00', '2023-07-01 20:30:00',
#                '2023-07-01 21:30:00', '2023-07-01 22:30:00',
#                '2023-07-01 23:30:00', '2023-07-02 00:30:00',
#                '2023-07-02 01:30:00', '2023-07-02 02:30:00',
#                '2023-07-02 03:30:00', '2023-07-02 04:30:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# 이 DatetimeIndex를 Series의 인덱스로 사용할수 있습니다:

# %%
temp_s=pd.Series(temperatures, dates)
temp_s
# Out:
# 2023-07-01 17:30:00    4.4
# 2023-07-01 18:30:00    5.1
# 2023-07-01 19:30:00    6.1
# 2023-07-01 20:30:00    6.2
# 2023-07-01 21:30:00    6.1
# 2023-07-01 22:30:00    6.1
# 2023-07-01 23:30:00    5.7
# 2023-07-02 00:30:00    5.2
# 2023-07-02 01:30:00    4.7
# 2023-07-02 02:30:00    4.1
# 2023-07-02 03:30:00    3.9
# 2023-07-02 04:30:00    3.5
# Freq: H, dtype: float64

# %% [markdown]
# 이 시리즈를 그래프로 출력해 보자.

# %%
temp_s.plot(kind='bar')
plt.show()

# %%
pd.Series(pd.period_range('2023-1-1', freq='M', periods=5))
# Out:
# 0    2023-01
# 1    2023-02
# 2    2023-03
# 3    2023-04
# 4    2023-05
# dtype: period[M]

# %% [markdown]
# ### **리샘플링**
#
# 판다스는 매우 간단하게 시계열을 리샘플링할 수 있다. resample() 메서드를 호출하고 새로운 주기를 지정하면 된다.

# %%
time_2h=temp_s.resample('2H')
time_2h

# %% [markdown]
# 리샘플링 연산은 사실 지연된 연산이다. 그래서 Series 객체 대신 DatetimeIndexResampler 객체가 반환된다. 실제 리샘플링 연산을 수행하려면 mean() 같은 메서드를 호출할 수 있다. 이 메서드는 연속적인 시간 쌍에 대해 평균을 계산한다.

# %%
time_2h=time_2h.mean()
time_2h
# Out:
# 2023-07-01 16:00:00    4.40
# 2023-07-01 18:00:00    5.60
# 2023-07-01 20:00:00    6.15
# 2023-07-01 22:00:00    5.90
# 2023-07-02 00:00:00    4.95
# 2023-07-02 02:00:00    4.00
# 2023-07-02 04:00:00    3.50
# Freq: 2H, dtype: float64

# %% [markdown]
# 결과를 그래프로 출력해 보죠:

# %%
time_2h.plot(kind='bar')
plt.show()

# %% [markdown]
# 2시간 간격으로 수집된 값을 확인하면, 예를 들어 18시의 데이터를 보면 6:30pm에서 5.1이고 7:30pm에서 6.1이다. 리샘플링 후에 5.1과 6.1의 평균인 5.6 하나를 얻었다. 평균말고 어떤 집계 함수(aggregation function)도 사용할 수 있다. 예를 들어 각 기간에서 최솟값을 찾을 수 있다.

# %%
time_2h=temp_s.resample('3H').min()
time_2h
# Out:
# 2023-07-01 15:00:00    4.4
# 2023-07-01 18:00:00    5.1
# 2023-07-01 21:00:00    5.7
# 2023-07-02 00:00:00    4.1
# 2023-07-02 03:00:00    3.5
# Freq: 3H, dtype: float64

# %% [markdown]
# 또는 동일한 효과를 내는 `apply()` 메서드를 사용할 수 있다.

# %%
time_2h=temp_s.resample('2H').apply(np.min)
time_2h
# Out:
# 2023-07-01 16:00:00    4.4
# 2023-07-01 18:00:00    5.1
# 2023-07-01 20:00:00    6.1
# 2023-07-01 22:00:00    5.7
# 2023-07-02 00:00:00    4.7
# 2023-07-02 02:00:00    3.9
# 2023-07-02 04:00:00    3.5
# Freq: 2H, dtype: float64

# %% [markdown]
# ### **업샘플링과 보간**
#
# 업샘플링 : 샘플링의 빈도를 높인다.

# %%
time_15min=temp_s.resample("15Min").mean()
time_15min
# Out:
# 2023-07-01 17:30:00    4.4
# 2023-07-01 17:45:00    NaN
# 2023-07-01 18:00:00    NaN
# 2023-07-01 18:15:00    NaN
# 2023-07-01 18:30:00    5.1
# 2023-07-01 18:45:00    NaN
# 2023-07-01 19:00:00    NaN
# 2023-07-01 19:15:00    NaN
# 2023-07-01 19:30:00    6.1
# 2023-07-01 19:45:00    NaN
# 2023-07-01 20:00:00    NaN
# 2023-07-01 20:15:00    NaN
# 2023-07-01 20:30:00    6.2
# 2023-07-01 20:45:00    NaN
# 2023-07-01 21:00:00    NaN
# 2023-07-01 21:15:00    NaN
# 2023-07-01 21:30:00    6.1
# 2023-07-01 21:45:00    NaN
# 2023-07-01 22:00:00    NaN
# 2023-07-01 22:15:00    NaN
# 2023-07-01 22:30:00    6.1
# 2023-07-01 22:45:00    NaN
# 2023-07-01 23:00:00    NaN
# 2023-07-01 23:15:00    NaN
# 2023-07-01 23:30:00    5.7
# 2023-07-01 23:45:00    NaN
# 2023-07-02 00:00:00    NaN
# 2023-07-02 00:15:00    NaN
# 2023-07-02 00:30:00    5.2
# 2023-07-02 00:45:00    NaN
# 2023-07-02 01:00:00    NaN
# 2023-07-02 01:15:00    NaN
# 2023-07-02 01:30:00    4.7
# 2023-07-02 01:45:00    NaN
# 2023-07-02 02:00:00    NaN
# 2023-07-02 02:15:00    NaN
# 2023-07-02 02:30:00    4.1
# 2023-07-02 02:45:00    NaN
# 2023-07-02 03:00:00    NaN
# 2023-07-02 03:15:00    NaN
# 2023-07-02 03:30:00    3.9
# 2023-07-02 03:45:00    NaN
# 2023-07-02 04:00:00    NaN
# 2023-07-02 04:15:00    NaN
# 2023-07-02 04:30:00    3.5
# Freq: 15T, dtype: float64

# %% [markdown]
# NaN 값을 채우기 위한 한 방법은 보간법으로 값을 채우는 것이다. 이렇게 하려면 interpolate() 메서드를 호출한다. 기본값은 선형 보간이지만 3차 보간(cubic interpolation) 같은 다른 방법을 선택할 수 있다.

# %%
time_15min=temp_s.resample('15Min').interpolate(method='cubic')
time_15min
# Out:
# 2023-07-01 17:30:00    4.400000
# 2023-07-01 17:45:00    4.452911
# 2023-07-01 18:00:00    4.605113
# 2023-07-01 18:15:00    4.829758
# 2023-07-01 18:30:00    5.100000
# 2023-07-01 18:45:00    5.388992
# 2023-07-01 19:00:00    5.669887
# 2023-07-01 19:15:00    5.915839
# 2023-07-01 19:30:00    6.100000
# 2023-07-01 19:45:00    6.203621
# 2023-07-01 20:00:00    6.240339
# 2023-07-01 20:15:00    6.231887
# 2023-07-01 20:30:00    6.200000
# 2023-07-01 20:45:00    6.163711
# 2023-07-01 21:00:00    6.131257
# 2023-07-01 21:15:00    6.108174
# 2023-07-01 21:30:00    6.100000
# 2023-07-01 21:45:00    6.108722
# 2023-07-01 22:00:00    6.122133
# 2023-07-01 22:15:00    6.124477
# 2023-07-01 22:30:00    6.100000
# 2023-07-01 22:45:00    6.037340
# 2023-07-01 23:00:00    5.942712
# 2023-07-01 23:15:00    5.826729
# 2023-07-01 23:30:00    5.700000
# 2023-07-01 23:45:00    5.571608
# 2023-07-02 00:00:00    5.444518
# 2023-07-02 00:15:00    5.320170
# 2023-07-02 00:30:00    5.200000
# 2023-07-02 00:45:00    5.084043
# 2023-07-02 01:00:00    4.966715
# 2023-07-02 01:15:00    4.841029
# 2023-07-02 01:30:00    4.700000
# 2023-07-02 01:45:00    4.540660
# 2023-07-02 02:00:00    4.376123
# 2023-07-02 02:15:00    4.223525
# 2023-07-02 02:30:00    4.100000
# 2023-07-02 02:45:00    4.017381
# 2023-07-02 03:00:00    3.966292
# 2023-07-02 03:15:00    3.932058
# 2023-07-02 03:30:00    3.900000
# 2023-07-02 03:45:00    3.855442
# 2023-07-02 04:00:00    3.783708
# 2023-07-02 04:15:00    3.670119
# 2023-07-02 04:30:00    3.500000
# Freq: 15T, dtype: float64

# %%
temp_s.plot(label='period : 1hour')
time_15min.plot(label='period : 15min')
plt.legend()
plt.show()

# %% [markdown]
# ### **기간**
#
# pd.period_range() 함수는 DatetimeIndex가 아니라 PeriodIndex를 반환한다. 예를 들어 2022년과 2023년의 전체 분기를 가져와 보자..

# %%
quarters=pd.period_range('2022Q1', periods=8, freq='Q')
quarters
# Out:
# PeriodIndex(['2022Q1', '2022Q2', '2022Q3', '2022Q4', '2023Q1', '2023Q2',
#              '2023Q3', '2023Q4'],
#             dtype='period[Q-DEC]')

# %% [markdown]
# PeriodIndex에 숫자 N을 추가하면 PeriodIndex 빈도의 N 배만큼 이동시킨다.

# %%
quarters+3
# Out:
# PeriodIndex(['2022Q4', '2023Q1', '2023Q2', '2023Q3', '2023Q4', '2024Q1',
#              '2024Q2', '2024Q3'],
#             dtype='period[Q-DEC]')

# %% [markdown]
# asfreq() 메서드를 사용하면 PeriodIndex의 빈도를 바꿀 수 있다. 모든 기간이 늘어나거나 줄어든다. 예를 들어 분기 기간을 모두 월별 기간으로 바꾸어 보자.

# %%
quarters.asfreq('M')
# Out:
# PeriodIndex(['2022-03', '2022-06', '2022-09', '2022-12', '2023-03', '2023-06',
#              '2023-09', '2023-12'],
#             dtype='period[M]')

# %% [markdown]
# 기본적으로 asfreq는 각 기간의 끝에 맞춘다. 기간의 시작에 맞추도록 변경할 수 있다.

# %%
quarters.asfreq('M', how='start')
# Out:
# PeriodIndex(['2022-01', '2022-04', '2022-07', '2022-10', '2023-01', '2023-04',
#              '2023-07', '2023-10'],
#             dtype='period[M]')

# %% [markdown]
# ### **DataFrame 객체**
#
# 데이터프레임 객체는 스프레드시트를 표현한다. 셀 값, 열 이름, 행 인덱스 레이블을 가진다. 다른 열을 바탕으로 열을 계산하는 식을 쓸 수 있고 피봇 테이블을 만들고, 행을 그룹핑하고, 그래프를 그릴 수 있다. DataFrame을 Series의 딕셔너리로 볼 수 있다.
#
# ### **DataFrame 만들기**
#
# Series 객체의 딕셔너리를 전달하여 데이터프레임을 만들 수 있다.

# %%
people_dict={'weight':pd.Series([68,83,112], index=['alice','bob','charles']),
             'birthyear':pd.Series([1984,1985,1992], index=['bob','alice','charles'], name='year'),
             'children':pd.Series([0,3], index=['charles','bob']),
             'hobby':pd.Series(['biking','dancing'], index=['alice','bob'])}

# %%
people=pd.DataFrame(people_dict)
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   biking
# bob          83       1984       3.0  dancing
# charles     112       1992       0.0      NaN

# %% [markdown]
# 몇가지 알아 두어야 할 것은 다음과 같다.
#
# * Series는 인덱스를 기반으로 자동으로 정렬된다.
# * 누락된 값은 NaN으로 표현된다.
# * Series 이름은 무시된다("year"란 이름은 삭제된다).

# %% [markdown]
# 예상하는 방식으로 열을 참조할 수 있고 Serires 객체가 반환된다.

# %%
a=people[['weight','birthyear']]
print(a)
# Out:
#          weight  birthyear
# alice        68       1985
# bob          83       1984
# charles     112       1992

# %% [markdown]
# 동시에 여러 개의 열을 선택할 수 있다.

# %% [markdown]
# 열 리스트나 행 인덱스 레이블을 DataFrame 생성자에 전달하면 해당 열과 행으로 채워진 데이터프레임이 반환된다. 예를 들면:

# %%
d2=pd.DataFrame(people_dict,
                columns=['birthyear','weight','height'],
                index=['bob','alice','eugene'])
d2
# Out:
#         birthyear  weight height
# bob        1984.0    83.0    NaN
# alice      1985.0    68.0    NaN
# eugene        NaN     NaN    NaN

# %% [markdown]
# DataFrame을 만드는 또 다른 편리한 방법은 ndarray나 리스트의 리스트로 모든 값을 생성자에게 전달하고 열 이름과 행 인덱스 레이블을 각기 지정하는 것이다.

# %%
values=[[1985, np.nan, 'biking', 68],
        [1984, 3, 'dancing', 83],
        [1992, 0, np.nan, 112]]
d3=pd.DataFrame(values,
                columns=['year','children','hobby','weight'],
                index=['alice','bob','charles'])
d3
# Out:
#          year  children    hobby  weight
# alice    1985       NaN   biking      68
# bob      1984       3.0  dancing      83
# charles  1992       0.0      NaN     112

# %% [markdown]
# ndarray 대신에 DataFrame 객체를 전달할 수도 있다.

# %%
d4=pd.DataFrame(d3,
                columns=['hobby','children'],
                index=['alice','bob'])
d4
# Out:
#          hobby  children
# alice   biking       NaN
# bob    dancing       3.0

# %% [markdown]
# 딕셔너리의 딕셔너리(또는 리스트의 리스트)로 DataFrame을 만들 수 있다.

# %%
people=pd.DataFrame({'birthyear':{'alice':1985, 'bob':1984, 'charles':1992},
                     'hobby':{'alice':'biking','bob':'dancing'},
                     'weight':{'alice':68, 'bob':83, 'charles':112},
                     'children':{'bob':3, 'charles':0}})
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   biking      68       NaN
# bob           1984  dancing      83       3.0
# charles       1992      NaN     112       0.0

# %% [markdown]
# ### **멀티 인덱싱**
#
# 모든 열이 같은 크기의 튜플이면 멀티 인덱스로 인식한다. 열 인덱스 레이블에도 같은 방식이 적용된다. 예를 들면,

# %%
d5=pd.DataFrame({('public', 'birthyear'):{('paris', 'alice'):1985,('paris','bob'):1984,('london','charles'):1992},
                 ('public','hobby'):{('paris', 'alice'):'biking',('paris','bob'):'dancing'},
                 ('private', 'weight'):{('paris', 'alice'):68,('paris','bob'):83,('london','charles'):112},
                 ('private', 'children'):{('paris', 'alice'):np.nan,('paris','bob'):3,('london','charles'):0}})
d5
# Out:
#                   public          private
#                birthyear    hobby  weight children
# paris  alice        1985   biking      68      NaN
#        bob          1984  dancing      83      3.0
# london charles      1992      NaN     112      0.0

# %% [markdown]
# 이제 "public" 열을 모두 담은 DataFrame을 손쉽게 만들 수 있다.

# %%
d5['public']
# Out:
#                 birthyear    hobby
# paris  alice         1985   biking
#        bob           1984  dancing
# london charles       1992      NaN

# %%
d5['public']['hobby']
# Out:
# paris   alice       biking
#         bob        dancing
# london  charles        NaN
# Name: hobby, dtype: object

# %% [markdown]
# ### **레벨 낮추기**
#
# d5를 다시 확인해 보자.

# %%
d5
# Out:
#                   public          private
#                birthyear    hobby  weight children
# paris  alice        1985   biking      68      NaN
#        bob          1984  dancing      83      3.0
# london charles      1992      NaN     112      0.0

# %% [markdown]
# 열의 레벨(level)이 2개이고 인덱스 레벨이 2개다. droplevel()을 사용해 열 레벨을 낮출 수 있다(인덱스도 마찬가지이다)

# %%
d5.columns=d5.columns.droplevel(level=0)
d5
# Out:
#                 birthyear    hobby  weight  children
# paris  alice         1985   biking      68       NaN
#        bob           1984  dancing      83       3.0
# london charles       1992      NaN     112       0.0

# %% [markdown]
# ### **전치**
#
# T 속성을 사용해 열과 인덱스를 바꿀 수 있다.

# %%
d6=d5.T
d6
# Out:
#             paris           london
#             alice      bob charles
# birthyear    1985     1984    1992
# hobby      biking  dancing     NaN
# weight         68       83     112
# children      NaN      3.0     0.0

# %% [markdown]
# ### **레벨 스택과 언스택**
#
# stack() 메서드는 가장 낮은 열 레벨을 가장 낮은 인덱스 뒤에 추가하는 기능을 수행한다.

# %%
d7=d6.stack()
d7
# Out:
#                   london    paris
# birthyear alice      NaN     1985
#           bob        NaN     1984
#           charles   1992      NaN
# hobby     alice      NaN   biking
#           bob        NaN  dancing
# weight    alice      NaN       68
#           bob        NaN       83
#           charles    112      NaN
# children  bob        NaN      3.0
#           charles    0.0      NaN

# %%
d7.unstack()
# Out:
#           london                paris
#            alice  bob charles   alice      bob charles
# birthyear    NaN  NaN    1992    1985     1984     NaN
# children     NaN  NaN     0.0     NaN      3.0     NaN
# hobby        NaN  NaN     NaN  biking  dancing     NaN
# weight       NaN  NaN     112      68       83     NaN

# %% [markdown]
# NaN 값이 생겼다. 이전에 없던 조합이 생겼기 때문이다(예를 들어 London에 bob이 없었다).
#
# unstack()을 호출하면 반대가 된다. 여기에서도 많은 NaN 값이 생성된다.

# %% [markdown]
# 대부분의 메서드는 수정된 복사본을 반환한다. stack()과 unstack() 메서드는 객체를 수정하지 않는다. 대신 복사본을 만들어 반환한다. 판다스에 있는 대부분의 메서드들이 이렇게 동작한다.

# %% [markdown]
# ### **행 참조하기**

# %%
a=people.loc['bob']
a
# Out:
# birthyear       1984
# hobby        dancing
# weight            83
# children         3.0
# Name: bob, dtype: object

# %% [markdown]
# loc 속성으로 열 대신 행을 참조할 수 있다. DataFrame의 열 이름이 행 인덱스 레이블로 매핑된 Series 객체가 반환된다.

# %%
people.iloc[1:3]
# Out:
#          birthyear    hobby  weight  children
# bob           1984  dancing      83       3.0
# charles       1992      NaN     112       0.0

# %% [markdown]
# `iloc` 속성을 사용해 정수 인덱스로 행을 참조할 수 있다.

# %%
people.iloc[0]
# Out:
# birthyear      1985
# hobby        biking
# weight           68
# children        NaN
# Name: alice, dtype: object

# %% [markdown]
# 행을 슬라이싱할 수 있으며 DataFrame 객체가 반환된다.

# %% [markdown]
# 마자믹으로 불리언 배열을 전달하여 해당하는 행을 가져올 수 있다.

# %%
people[np.array([True, False, True])]
# Out:
#          birthyear   hobby  weight  children
# alice         1985  biking      68       NaN
# charles       1992     NaN     112       0.0

# %% [markdown]
# 불리언 표현식을 사용할 때 아주 유용하다.

# %%
people[people['weight']>100]
# Out:
#          birthyear hobby  weight  children
# charles       1992   NaN     112       0.0

# %% [markdown]
# ### **열 추가, 삭제**
#
# DataFrame을 Series의 딕셔너리처럼 다룰 수 있다. 따라서 다음과 같이 쓸 수 있다.

# %%
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   biking      68       NaN
# bob           1984  dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people['age']=2023-people['birthyear']
people['over_40']=people['age']>40
del people['children']
birthyears=people.pop('birthyear')

# %%
people
# Out:
#            hobby  weight  age  over_40
# alice     biking      68   38    False
# bob      dancing      83   39    False
# charles      NaN     112   31    False

# %%
people['birthyear']=birthyears
people
# Out:
#            hobby  weight  age  over_40  birthyear
# alice     biking      68   38    False       1985
# bob      dancing      83   39    False       1984
# charles      NaN     112   31    False       1992

# %% [markdown]
# 새로운 열을 추가할 때 행의 개수는 같아야 한다. 누락된 행은 NaN으로 채워지고 추가적인 행은 무시된다.

# %%
people['pets']=pd.Series({'bob':0, 'charles':5, 'eugene':1})
people
# Out:
#            hobby  weight  age  over_40  birthyear  pets
# alice     biking      68   38    False       1985   NaN
# bob      dancing      83   39    False       1984   0.0
# charles      NaN     112   31    False       1992   5.0

# %% [markdown]
# 새로운 열을 추가할 때 기본적으로 (오른쪽) 끝에 추가된다. insert() 메서드를 사용해 다른 곳에 열을 추가할 수 있다.

# %%
people.insert(1, 'height', [172, 181, 185])
people
# Out:
#            hobby  height  weight  age  over_40  birthyear  pets
# alice     biking     172      68   38    False       1985   NaN
# bob      dancing     181      83   39    False       1984   0.0
# charles      NaN     185     112   31    False       1992   5.0

# %% [markdown]
# ### **새로운 열 할당하기**
#
# assign() 메서드를 호출하여 새로운 열을 만들 수도 있다. 이는 새로운 DataFrame 객체를 반환하며 원본 객체는 변경되지 않는다.

# %%
people.assign(body_mass_index=people['weight']/(people['height']/100)**2,
              has_pets=people['pets']>0)
# Out:
#            hobby  height  weight  age  over_40  birthyear  pets  \
# alice     biking     172      68   38    False       1985   NaN
# bob      dancing     181      83   39    False       1984   0.0
# charles      NaN     185     112   31    False       1992   5.0
#
#          body_mass_index  has_pets
# alice          22.985398     False
# bob            25.335002     False
# charles        32.724617      True

# %%
people
# Out:
#            hobby  height  weight  age  over_40  birthyear  pets
# alice     biking     172      68   38    False       1985   NaN
# bob      dancing     181      83   39    False       1984   0.0
# charles      NaN     185     112   31    False       1992   5.0

# %% [markdown]
# ### **표현식 평가**
#
# 판다스가 제공하는 뛰어난 기능 하나는 표현식 평가이다. 이는 numexpr 라이브러리에 의존하기 때문에 설치가 되어 있어야 한다.

# %%
people.eval('weight/(height/100)**2>25')
# Out:
# alice      False
# bob         True
# charles     True
# dtype: bool

# %% [markdown]
# 할당 표현식도 지원된다. inplace=True로 지정하면 수정된 복사본을 만들지 않고 바로 DataFrame을 변경한다.

# %%
people.eval('body_mass_index=weight/(height/100)**2', inplace=True)
people
# Out:
#            hobby  height  weight  age  over_40  birthyear  pets  \
# alice     biking     172      68   38    False       1985   NaN
# bob      dancing     181      83   39    False       1984   0.0
# charles      NaN     185     112   31    False       1992   5.0
#
#          body_mass_index
# alice          22.985398
# bob            25.335002
# charles        32.724617

# %% [markdown]
# @를 접두어로 사용하여 지역 변수나 전역 변수를 참조할 수 있다.

# %%
overweight_num=30
people.eval('overweight=body_mass_index>@overweight_num', inplace=True)

# %%
people
# Out:
#            hobby  height  weight  age  over_40  birthyear  pets  \
# alice     biking     172      68   38    False       1985   NaN
# bob      dancing     181      83   39    False       1984   0.0
# charles      NaN     185     112   31    False       1992   5.0
#
#          body_mass_index  overweight
# alice          22.985398       False
# bob            25.335002       False
# charles        32.724617        True

# %% [markdown]
# ### **DataFrame 쿼리하기**
#
# query() 메서드를 사용하면 쿼리 표현식에 기반하여 DataFrame을 필터링할 수 있다.

# %%
people.query('age>35 or pets==0')
# Out:
#          hobby  height  weight  age  over_40  birthyear  pets  \
# alice   biking     172      68   38    False       1985   NaN
# bob    dancing     181      83   39    False       1984   0.0
#
#        body_mass_index  overweight
# alice        22.985398       False
# bob          25.335002       False

# %% [markdown]
# ### **DataFrame 정렬**
#
# sort_index 메서드를 호출하여 DataFrame을 정렬할 수 있다. 기본적으로 인덱스 레이블을 기준으로 오름차순으로 행을 정렬한다. 여기에서는 내림차순으로 정렬해 보자.

# %%
people.sort_index(ascending=False)
# Out:
#            hobby  height  weight  age  over_40  birthyear  pets  \
# charles      NaN     185     112   31    False       1992   5.0
# bob      dancing     181      83   39    False       1984   0.0
# alice     biking     172      68   38    False       1985   NaN
#
#          body_mass_index  overweight
# charles        32.724617        True
# bob            25.335002       False
# alice          22.985398       False

# %% [markdown]
# sort_index는 DataFrame의 정렬된 복사본을 반환한다. people을 직접 수정하려면 inplace 매개변수를 True로 지정한다. 또한 axis=1로 지정하여 열 대신 행을 정렬할 수 있다.

# %%
people.sort_index(axis=1, inplace=True)
people
# Out:
#          age  birthyear  body_mass_index  height    hobby  over_40  \
# alice     38       1985        22.985398     172   biking    False
# bob       39       1984        25.335002     181  dancing    False
# charles   31       1992        32.724617     185      NaN    False
#
#          overweight  pets  weight
# alice         False   NaN      68
# bob           False   0.0      83
# charles        True   5.0     112

# %% [markdown]
# 레이블이 아니라 값을 기준으로 DataFrame을 정렬하려면 sort_values에 정렬하려는 열을 지정한다.

# %%
people.sort_values(by='age', inplace=True)
people
# Out:
#          age  birthyear  body_mass_index  height    hobby  over_40  \
# charles   31       1992        32.724617     185      NaN    False
# alice     38       1985        22.985398     172   biking    False
# bob       39       1984        25.335002     181  dancing    False
#
#          overweight  pets  weight
# charles        True   5.0     112
# alice         False   NaN      68
# bob           False   0.0      83

# %% [markdown]
# ### **DataFrame 그래프 그리기**
#
# Series와 마찬가지로 판다스는 DataFrame 기반으로 멋진 그래프를 손쉽게 그릴 수 있다.
# 예를 들어 plot 메서드를 호출하여 DataFrame의 데이터에서 선 그래프를 쉽게 그릴 수 있다.

# %%
import matplotlib.pyplot as plt

# %%
people.plot(kind='line', x='body_mass_index',y=['height', 'weight'])
plt.show()

# %% [markdown]
# 맷플롯립의 함수가 지원하는 다른 매개변수를 사용할 수 있다. 예를 들어, 산점도를 그릴 때 맷플롯립의 scatter() 함수의 s 매개변수를 사용해 크기를 지정할 수 있다.

# %%
people.plot(kind='scatter', x='height', y='weight', s=[40,120,200])
plt.show()

# %% [markdown]
# ### **DataFrame 연산**
#
# DataFrame이 넘파이 배열을 흉내내려는 것은 아니지만 몇 가지 비슷한 점이 있다.

# %%
grades_array=np.array([[8,8,9],[10,9,9],[4,8,2],[9,10,10]])
grades=pd.DataFrame(grades_array, columns=['sep','oct','nov'], index=['alice','bob','charles','darwin'])
grades
# Out:
#          sep  oct  nov
# alice      8    8    9
# bob       10    9    9
# charles    4    8    2
# darwin     9   10   10

# %% [markdown]
# DataFrame에 넘파이 수학 함수를 적용하면 모든 값에 이 함수가 적용된다.

# %%
np.sqrt(grades)
# Out:
#               sep       oct       nov
# alice    2.828427  2.828427  3.000000
# bob      3.162278  3.000000  3.000000
# charles  2.000000  2.828427  1.414214
# darwin   3.000000  3.162278  3.162278

# %% [markdown]
# 비슷하게 DataFrame에 하나의 값을 더하면 DataFrame의 모든 원소에 이 값이 더해진다.

# %%
grades+1
# Out:
#          sep  oct  nov
# alice      9    9   10
# bob       11   10   10
# charles    5    9    3
# darwin    10   11   11

# %% [markdown]
# 물론 산술 연산(`*`,`/`,`**`...)과 조건 연산(`>`, `==`...)을 포함해 모든 이항 연산에도 마찬가지이다.

# %%
grades>=5
# Out:
#            sep   oct    nov
# alice     True  True   True
# bob       True  True   True
# charles  False  True  False
# darwin    True  True   True

# %% [markdown]
# DataFrame의 max, sum, mean 같은 집계 연산은 각 열에 적용되어 Series 객체가 반환된다.

# %%
grades.mean()
# Out:
# sep    7.75
# oct    8.75
# nov    7.50
# dtype: float64

# %% [markdown]
# all 메서드도 집계 연산이다. 모든 값이 True인지 아닌지 확인한다. 모든 학생의 점수가 5 이상인 월을 찾아 보자.

# %%
(grades>5).all(axis=1)
# Out:
# alice       True
# bob         True
# charles    False
# darwin      True
# dtype: bool

# %% [markdown]
# any 메서드는 하나라도 참이면 True를 반환한다. 한 번이라도 10점을 받은 사람을 찾아 보자.

# %%
(grades==10).any(axis=1)
# Out:
# alice      False
# bob         True
# charles    False
# darwin      True
# dtype: bool

# %% [markdown]
# DataFrame에 Series 객체를 더하면 (또는 다른 이항 연산을 수행하면) 판다스는 DataFrame에 있는 모든 행에 이 연산을 브로드캐스팅한다. 이는 Series 객체가 DataFrame의 행의 개수와 크기가 같을 때만 동작한다. 예를 들어 DataFrame의 mean(Series 객체)을 빼보자.

# %%
grades-grades.mean()
# Out:
#           sep   oct  nov
# alice    0.25 -0.75  1.5
# bob      2.25  0.25  1.5
# charles -3.75 -0.75 -5.5
# darwin   1.25  1.25  2.5

# %% [markdown]
# 모든 9월 성적에서 7.75를 빼고, 10월 성적에서 8.75를 빼고, 11월 성적에서 7.50을 뺀다.

# %% [markdown]
# 모든 성적의 전체 평균을 빼고 싶다면 다음과 같은 방법을 사용한다.

# %%
grades-grades.values.mean()
# Out:
#          sep  oct  nov
# alice    0.0  0.0  1.0
# bob      2.0  1.0  1.0
# charles -4.0  0.0 -6.0
# darwin   1.0  2.0  2.0

# %% [markdown]
# ### **자동 정렬**
#
# Series와 비슷하게 여러 개의 DataFrame에 대한 연산을 수행하면 판다스는 자동으로 행 인덱스 레이블로 정렬하지만 열 이름으로도 정렬할 수 있다. 10월부터 12월까지 보너스 포인트를 담은 DataFrame을 만들어 보자.

# %%
grades
# Out:
#          sep  oct  nov
# alice      8    8    9
# bob       10    9    9
# charles    4    8    2
# darwin     9   10   10

# %%
bonus_array=np.array([[0,np.nan,2],[np.nan,1,0],[0,1,0],[3,3,0]])
bonus_points=pd.DataFrame(bonus_array, columns=['oct','nov','dec'], index=['bob','colin','darwin','charles'])
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
grades+bonus_points
# Out:
#          dec   nov   oct  sep
# alice    NaN   NaN   NaN  NaN
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# colin    NaN   NaN   NaN  NaN
# darwin   NaN  11.0  10.0  NaN

# %% [markdown]
# 덧셈 연산이 수행되었지만 너무 많은 원소가 NaN이 되었다. DataFrame을 정렬할 때 일부 열과 행이 한 쪽에만 있기 때문이다. 다른 쪽에는 누락되었다고 간주한다(NaN). NaN에 어떤 수를 더하면 NaN이 된다.
#
# ### **누락된 데이터 다루기**
#
# 실제 데이터에서 누락된 데이터를 다루는 경우는 자주 발생한다. 판다스는 누락된 데이터를 다룰 수 있는 몇 가지 방법을 제공한다.
#
# 위 데이터에 있는 문제를 해결해 보자. 예를 들어, 누락된 데이터는 NaN이 아니라 0이 되어야 한다고 결정할 수 있다. fillna() 메서드를 사용해 모든 NaN 값을 어떤 값으로 바꿀 수 있다.

# %%
(grades+bonus_points).fillna(0)
# Out:
#          dec   nov   oct  sep
# alice    0.0   0.0   0.0  0.0
# bob      0.0   0.0   9.0  0.0
# charles  0.0   5.0  11.0  0.0
# colin    0.0   0.0   0.0  0.0
# darwin   0.0  11.0  10.0  0.0

# %% [markdown]
# 9월 점수를 0으로 만드는 것은 맞지 않다. 누락된 점수는 그대로 두고, 누락된 보너스 포인트는 0으로 바꿀 수 있다.

# %%
fixed_bonus_points=bonus_points.fillna(0)
fixed_bonus_points.insert(0, 'sep', 0)
fixed_bonus_points.loc['alice']=0
print(fixed_bonus_points)
grades+fixed_bonus_points
# Out:
#          sep  oct  nov  dec
# bob        0  0.0  0.0  2.0
# colin      0  0.0  1.0  0.0
# darwin     0  0.0  1.0  0.0
# charles    0  3.0  3.0  0.0
# alice      0  0.0  0.0  0.0
#          dec   nov   oct   sep
# alice    NaN   9.0   8.0   8.0
# bob      NaN   9.0   9.0  10.0
# charles  NaN   5.0  11.0   4.0
# colin    NaN   NaN   NaN   NaN
# darwin   NaN  11.0  10.0   9.0

# %% [markdown]
# 누락된 값을 다루는 또 다른 방법은 보간법이다. bonus_points DataFrame을 다시 보자.

# %%
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %% [markdown]
# interpolate 메서드를 사용해 보자. 기본적으로 수직 방향(axis=0)으로 보간한다. 따라서 수평으로(axis=1)으로 보간하도록 지정한다.

# %%
bonus_points.interpolate(axis=1)
# Out:
#          oct  nov  dec
# bob      0.0  1.0  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %% [markdown]
# bob의 보너스 포인트는 10월에 0이고 12월에 2이다. 11월을 보간하면 평균 보너스 포인트 1을 얻는다. colin의 보너스 포인트는 11월에 1이지만 9월에 포인트는 얼마인지 모른다. 따라서 보간할 수 없고 10월의 포인트는 그대로 누락된 값으로 남아 있다. 이를 해결하려면 보간하기 전에 9월의 보너스 포인트를 0으로 설정해야 한다.

# %%
better_bonus_points=bonus_points.copy()
better_bonus_points.insert(0,'sep',0)
better_bonus_points.loc['alice']=0
better_bonus_points.interpolate(axis=1, inplace=True)
better_bonus_points
# Out:
#          sep  oct  nov  dec
# bob      0.0  0.0  1.0  2.0
# colin    0.0  0.5  1.0  0.0
# darwin   0.0  0.0  1.0  0.0
# charles  0.0  3.0  3.0  0.0
# alice    0.0  0.0  0.0  0.0

# %% [markdown]
# 이제 모든 보너스 포인트가 합리적으로 보간되었다. 최종 점수를 확인해 보자.

# %%
grades+better_bonus_points
# Out:
#          dec   nov   oct   sep
# alice    NaN   9.0   8.0   8.0
# bob      NaN  10.0   9.0  10.0
# charles  NaN   5.0  11.0   4.0
# colin    NaN   NaN   NaN   NaN
# darwin   NaN  11.0  10.0   9.0

# %% [markdown]
# 9월 열이 오른쪽에 추가되었는데 좀 이상하다. 이는 더하려는 DataFrame이 정확히 같은 열을 가지고 있지 않기 때문이다(grade DataFrame에는 "dec" 열이 없다). 따라서 판다스는 알파벳 순서로 최종 열을 정렬한다. 이를 해결하려면 덧셈을 하기 전에 누락된 열을 추가하면 된다.

# %%
grades['dec']=np.nan
final_grades=grades+better_bonus_points
final_grades
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# colin     NaN   NaN   NaN  NaN
# darwin    9.0  10.0  11.0  NaN

# %% [markdown]
# 12월과 colin에 대해 할 수 있는 것이 많지 않다. 보너스 포인트를 만드는 것이 나쁘지만 점수를 합리적으로 올릴 수는 없다. dropna() 메서드를 사용해 모두 NaN인 행을 삭제한다.

# %%
final_grades_clean=final_grades.dropna(how='all')

# %%
final_grades_clean
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# darwin    9.0  10.0  11.0  NaN

# %% [markdown]
# 그다음 axis 매개변수를 1로 지정하여 모두 NaN인 열을 삭제한다.

# %%
final_grades_clean=final_grades_clean.dropna(axis=1, how='all')
final_grades_clean
# Out:
#           sep   oct   nov
# alice     8.0   8.0   9.0
# bob      10.0   9.0  10.0
# charles   4.0  11.0   5.0
# darwin    9.0  10.0  11.0

# %% [markdown]
# ### **groupby로 집계하기**
#
# SQL과 비슷하게 판다스는 데이터를 그룹핑하고 각 그룹에 대해 연산을 수행할 수 있다.
#
# 먼저 그루핑을 위해 각 사람의 데이터를 추가로 만든다. NaN 값을 어떻게 다루는지 보기 위해 final_grades DataFrame을 다시 사용한다.

# %%
final_grades['hobby']=['biking','dancing',np.nan,'dancing','biking']
final_grades
# Out:
#           sep   oct   nov  dec    hobby
# alice     8.0   8.0   9.0  NaN   biking
# bob      10.0   9.0  10.0  NaN  dancing
# charles   4.0  11.0   5.0  NaN      NaN
# colin     NaN   NaN   NaN  NaN  dancing
# darwin    9.0  10.0  11.0  NaN   biking

# %% [markdown]
# hobby로 이 DataFrame을 그룹핑해 보자.

# %%
grouped_grades=final_grades.groupby('hobby')

# %%
type(grouped_grades)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# 이제 hobby마다 평균 점수를 계산할 수 있다.

# %%
grouped_grades.mean()
# Out:
#           sep  oct   nov  dec
# hobby
# biking    8.5  9.0  10.0  NaN
# dancing  10.0  9.0  10.0  NaN

# %% [markdown]
# 아주 쉽다. 평균을 계산할 때 NaN 값은 그냥 무시된다는 것을 기억하자.

# %% [markdown]
# ### **함수**
#
# 큰 DataFrame을 다룰 때 내용을 간단히 요약하는 것이 도움이 된다. 판다스는 이를 위한 몇 가지 함수를 제공한다. 먼저 수치 값, 누락된 값, 텍스트 값이 섞인 큰 DataFrame을 만들자.
#  - fromfunction(함수, (행크기, 열크기))은 매개변수로 함수 형식을 가져와(행크기, 열크기)의 array를 만들어 준다.

# %%
big_data=np.fromfunction(lambda x,y:(x+y*y)%17*11, (10000,26))
big_df=pd.DataFrame(big_data, columns=list('abcdefghijklmnopqrstuvwxyz'))
big_df[big_df%16==0]=np.nan
big_df.insert(3, 'some_text', 'blabla')
big_df
# Out:
#          a     b     c some_text      d      e      f     g      h      i  \
# 0      NaN  11.0  44.0    blabla   99.0    NaN   88.0  22.0  165.0  143.0
# 1     11.0  22.0  55.0    blabla  110.0    NaN   99.0  33.0    NaN  154.0
# 2     22.0  33.0  66.0    blabla  121.0   11.0  110.0  44.0    NaN  165.0
# 3     33.0  44.0  77.0    blabla  132.0   22.0  121.0  55.0   11.0    NaN
# 4     44.0  55.0  88.0    blabla  143.0   33.0  132.0  66.0   22.0    NaN
# ...    ...   ...   ...       ...    ...    ...    ...   ...    ...    ...
# 9995   NaN   NaN  33.0    blabla   88.0  165.0   77.0  11.0  154.0  132.0
# 9996   NaN  11.0  44.0    blabla   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  11.0  22.0  55.0    blabla  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  22.0  33.0  66.0    blabla  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  33.0  44.0  77.0    blabla  132.0   22.0  121.0  55.0   11.0    NaN
#
#       ...     q     r     s     t      u      v      w     x      y      z
# 0     ...  11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 1     ...  22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 2     ...  33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 3     ...  44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
# 4     ...  55.0  44.0  55.0  88.0  143.0   33.0  132.0  66.0   22.0    NaN
# ...   ...   ...   ...   ...   ...    ...    ...    ...   ...    ...    ...
# 9995  ...   NaN   NaN   NaN  33.0   88.0  165.0   77.0  11.0  154.0  132.0
# 9996  ...  11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  ...  22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  ...  33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  ...  44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
#
# [10000 rows x 27 columns]

# %% [markdown]
# head() 메서드는 처음 5개 행을 반환한다.

# %%
big_df.head(3)
# Out:
#       a     b     c some_text      d     e      f     g      h      i  ...  \
# 0   NaN  11.0  44.0    blabla   99.0   NaN   88.0  22.0  165.0  143.0  ...
# 1  11.0  22.0  55.0    blabla  110.0   NaN   99.0  33.0    NaN  154.0  ...
# 2  22.0  33.0  66.0    blabla  121.0  11.0  110.0  44.0    NaN  165.0  ...
#
#       q     r     s     t      u     v      w     x      y      z
# 0  11.0   NaN  11.0  44.0   99.0   NaN   88.0  22.0  165.0  143.0
# 1  22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0    NaN  154.0
# 2  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0    NaN  165.0
#
# [3 rows x 27 columns]

# %% [markdown]
# 마지막 5개 행을 반환하는 tail() 함수도 있다. 원하는 행 개수를 전달할 수도 있다.

# %%
big_df.tail(2)
# Out:
#          a     b     c some_text      d     e      f     g     h      i  ...  \
# 9998  22.0  33.0  66.0    blabla  121.0  11.0  110.0  44.0   NaN  165.0  ...
# 9999  33.0  44.0  77.0    blabla  132.0  22.0  121.0  55.0  11.0    NaN  ...
#
#          q     r     s     t      u     v      w     x     y      z
# 9998  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0   NaN  165.0
# 9999  44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0  11.0    NaN
#
# [2 rows x 27 columns]

# %% [markdown]
# info() 메서드는 각 열의 내용을 요약하여 출력한다.

# %%
big_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   a          8823 non-null   float64
#  1   b          8824 non-null   float64
#  2   c          8824 non-null   float64
#  3   some_text  10000 non-null  object
#  4   d          8824 non-null   float64
#  5   e          8822 non-null   float64
#  6   f          8824 non-null   float64
#  7   g          8824 non-null   float64
#  8   h          8822 non-null   float64
#  9   i          8823 non-null   float64
#  10  j          8823 non-null   float64
#  11  k          8822 non-null   float64
#  12  l          8824 non-null   float64
#  13  m          8824 non-null   float64
#  14  n          8822 non-null   float64
#  15  o          8824 non-null   float64
#  16  p          8824 non-null   float64
#  17  q          8824 non-null   float64
#  18  r          8823 non-null   float64
#  19  s          8824 non-null   float64
#  20  t          8824 non-null   float64
#  21  u          8824 non-null   float64
#  22  v          8822 non-null   float64
#  23  w          8824 non-null   float64
#  24  x          8824 non-null   float64
#  25  y          8822 non-null   float64
#  26  z          8823 non-null   float64
# dtypes: float64(26), object(1)
# memory usage: 2.1+ MB

# %% [markdown]
# 마지막으로 describe() 메서드는 각 열에 대한 주요 집계 연산을 수행한 결과를 보여준다.
#
# * count: null(NaN)이 아닌 값의 개수
# * mean: null이 아닌 값의 평균
# * std: null이 아닌 값의 표준 편차
# * min: null이 아닌 값의 최솟값
# * 25%, 50%, 75%: null이 아닌 값의 25번째, 50번째, 75번째 백분위수
# * max: null이 아닌 값의 최댓값

# %%
big_df.describe()
# Out:
#                  a            b            c            d            e  \
# count  8823.000000  8824.000000  8824.000000  8824.000000  8822.000000
# mean     87.977559    87.972575    87.987534    88.012466    87.983791
# std      47.535911    47.535523    47.521679    47.521679    47.535001
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  f            g            h            i            j  ...  \
# count  8824.000000  8824.000000  8822.000000  8823.000000  8823.000000  ...
# mean     88.007480    87.977561    88.000000    88.022441    88.022441  ...
# std      47.519371    47.529755    47.536879    47.535911    47.535911  ...
# min      11.000000    11.000000    11.000000    11.000000    11.000000  ...
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000  ...
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000  ...
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000  ...
# max     165.000000   165.000000   165.000000   165.000000   165.000000  ...
#
#                  q            r            s            t            u  \
# count  8824.000000  8823.000000  8824.000000  8824.000000  8824.000000
# mean     87.972575    87.977559    87.972575    87.987534    88.012466
# std      47.535523    47.535911    47.535523    47.521679    47.521679
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  v            w            x            y            z
# count  8822.000000  8824.000000  8824.000000  8822.000000  8823.000000
# mean     87.983791    88.007480    87.977561    88.000000    88.022441
# std      47.535001    47.519371    47.529755    47.536879    47.535911
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ### **저장 & 로딩**
#
# 판다스는 DataFrame를 여러 가지 포맷으로 저장할 수 있다. CSV, Excel, JSON, HTML, HDF5, SQL 데이터베이스 같은 포맷이 가능하다.

# %%
my_df=pd.DataFrame([['biking',68.5,1985,np.nan],
                    ['dancing',83.1, 1984,3]],
                    columns=['hobby','height','birthyear','clildren'],
                    index=['alice','bob'])
my_df
# Out:
#          hobby  height  birthyear  clildren
# alice   biking    68.5       1985       NaN
# bob    dancing    83.1       1984       3.0

# %% [markdown]
# ### **저장**
#
# CSV, HTML, JSON로 저장해 보자.

# %%
my_df.to_csv('my_df.csv')
my_df.to_html('my_df.html')
my_df.to_json('my_df.json')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 저장된 내용을 확인해 보자.

# %%
for filename in ('my_df.csv','my_df.html','my_df.json'):
  print('#',filename)
  with open(filename, 'rt') as f:
    print(f.read())
    print()
# Out:
# # my_df.csv
# ,hobby,height,birthyear,clildren
# alice,biking,68.5,1985,
# bob,dancing,83.1,1984,3.0
#
#
# # my_df.html
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hobby</th>
#       <th>height</th>
#       <th>birthyear</th>
#       <th>clildren</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alice</th>
#       <td>biking</td>
#       <td>68.5</td>
#       <td>1985</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>bob</th>
#       <td>dancing</td>
#       <td>83.1</td>
#       <td>1984</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
#
# # my_df.json
# {"hobby":{"alice":"biking","bob":"dancing"},"height":{"alice":68.5,"bob":83.1},"birthyear":{"alice":1985,"bob":1984},"clildren":{"alice":null,"bob":3.0}}

# %% [markdown]
# 인덱스는 (이름 없이) CSV 파일의 첫 번째 열에 저장되었다. HTML에서는 <th> 태그와 JSON에서는 키로 저장되었다.
#
# 다른 포맷으로 저장하는 것도 비슷하다. 하지만 일부 포맷은 추가적인 라이브러리 설치가 필요할 수도 있다. 예를 들어, 엑셀로 저장하려면 openpyxl 라이브러리가 필요할수도 있다.

# %%
try:
  my_df.to_excel('my_df.xlsx', sheet_name='people')
except ImportError as e:
  print(e)

# %% [markdown]
# ### **로딩**
#
# CSV 파일을 DataFrame으로 로드해 보자.

# %%
my_file=pd.read_csv('my_df.csv', index_col=0)
my_file
# Out:
#          hobby  height  birthyear  clildren
# alice   biking    68.5       1985       NaN
# bob    dancing    83.1       1984       3.0

# %% [markdown]
# read_json, read_html, read_excel 함수도 있다. 인터넷에서 데이터를 바로 읽을 수도 있다. 예를 들어 깃허브에서 1,000개의 U.S. 도시를 로드해 보자.

# %%
us_cities=None
try:
  csv_url='http://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv'
  us_cities=pd.read_csv(csv_url, index_col=0)
  us_cities=us_cities
except IOError as e:
  print(e)
us_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Marysville to Compton
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State       1000 non-null   object
#  1   Population  1000 non-null   int64
#  2   lat         1000 non-null   float64
#  3   lon         1000 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 39.1+ KB

# %% [markdown]
# ### **DataFrame 합치기**
#
# ### **SQL 조인**
#
# 판다스의 강력한 기능 중 하나는 DataFrame에 대해 SQL 같은 조인(join)을 수행할 수 있는 것이다. 여러 종류의 조인이 지원된다. 이너 조인(inner join), 레프트/라이트 아우터 조인(left/right outer join), 풀 조인(full join)이다.

# %%
city_loc=pd.DataFrame([['ca','san francico',37.781334, -122.416728],
                       ['ny','new york',40.705649,-74.008344],
                       ['fl','miami',25.791100, -80.320733],
                       ['oh','cleveland',41.473508,-81.739791],
                       ['ut','salt lake city',40.755851,-111.896657]],
                      columns=['state','city','lat','lng'])
city_loc
# Out:
#   state            city        lat         lng
# 0    ca    san francico  37.781334 -122.416728
# 1    ny        new york  40.705649  -74.008344
# 2    fl           miami  25.791100  -80.320733
# 3    oh       cleveland  41.473508  -81.739791
# 4    ut  salt lake city  40.755851 -111.896657

# %%
city_pop=pd.DataFrame([[808976, 'san francico', 'california'],
                       [8363710, 'new york','new-york'],
                       [413210,'miami','florida'],
                       [2242193, 'houston','texas']],
                      index=[3,4,5,6], columns=['population','city','state'])
city_pop
# Out:
#    population          city       state
# 3      808976  san francico  california
# 4     8363710      new york    new-york
# 5      413210         miami     florida
# 6     2242193       houston       texas

# %% [markdown]
# 이제 merge() 함수를 사용해 이 DataFrame을 조인해 보자.

# %%
pd.merge(left=city_loc, right=city_pop, on='city')
# Out:
#   state_x          city        lat         lng  population     state_y
# 0      ca  san francico  37.781334 -122.416728      808976  california
# 1      ny      new york  40.705649  -74.008344     8363710    new-york
# 2      fl         miami  25.791100  -80.320733      413210     florida

# %% [markdown]
# 두 DataFrame은 state란 이름의 열을 가지고 있으므로 state_x와 state_y로 이름이 바뀌었다.
#
# 또한 Cleveland, Salt Lake City, Houston은 두 DataFrame에 모두 존재하지 않기 때문에 삭제되었다. SQL의 INNER JOIN과 동일하다. 도시를 삭제하지 않고 NaN으로 채우는 FULL OUTER JOIN을 원하면 how="outer"`로 지정한다.

# %%
pd.merge(left=city_loc, right=city_pop, how='outer',on='city')
# Out:
#   state_x            city        lat         lng  population     state_y
# 0      ca    san francico  37.781334 -122.416728    808976.0  california
# 1      ny        new york  40.705649  -74.008344   8363710.0    new-york
# 2      fl           miami  25.791100  -80.320733    413210.0     florida
# 3      oh       cleveland  41.473508  -81.739791         NaN         NaN
# 4      ut  salt lake city  40.755851 -111.896657         NaN         NaN
# 5     NaN         houston        NaN         NaN   2242193.0       texas

# %% [markdown]
# 물론 LEFT OUTER JOIN은 how="left"로 지정할 수 있다. 왼쪽의 DataFrame에 있는 도시만 남는다. 비슷하게 how="right"는 오른쪽 DataFrame에 있는 도시만 결과에 남는다. 예를 들면:

# %%
pd.merge(left=city_loc, right=city_pop, how='right',on='city')
# Out:
#   state_x          city        lat         lng  population     state_y
# 0      ca  san francico  37.781334 -122.416728      808976  california
# 1      ny      new york  40.705649  -74.008344     8363710    new-york
# 2      fl         miami  25.791100  -80.320733      413210     florida
# 3     NaN       houston        NaN         NaN     2242193       texas

# %% [markdown]
# 조인할 키가 DataFrame 인덱스라면 left_index=True나 right_index=True로 지정해야 한다. 키 열의 이름이 다르면 left_on과 right_on을 사용한다. 예를 들어:

# %%
city_pop2=city_pop.copy()
city_pop2.columns=['population','city_name','new_state']
pd.merge(left=city_loc, right=city_pop2, left_on='city', right_on='city_name')
# Out:
#   state          city        lat         lng  population     city_name  \
# 0    ca  san francico  37.781334 -122.416728      808976  san francico
# 1    ny      new york  40.705649  -74.008344     8363710      new york
# 2    fl         miami  25.791100  -80.320733      413210         miami
#
#     new_state
# 0  california
# 1    new-york
# 2     florida

# %% [markdown]
# ### **연결**
#
# DataFrame을 조인하는 대신 그냥 연결할 수도 있다. concat() 함수가 하는 일이다.

# %%
result_concat=pd.concat([city_loc, city_pop])

# %%
result_concat
# Out:
#         state            city        lat         lng  population
# 0          ca    san francico  37.781334 -122.416728         NaN
# 1          ny        new york  40.705649  -74.008344         NaN
# 2          fl           miami  25.791100  -80.320733         NaN
# 3          oh       cleveland  41.473508  -81.739791         NaN
# 4          ut  salt lake city  40.755851 -111.896657         NaN
# 3  california    san francico        NaN         NaN    808976.0
# 4    new-york        new york        NaN         NaN   8363710.0
# 5     florida           miami        NaN         NaN    413210.0
# 6       texas         houston        NaN         NaN   2242193.0

# %% [markdown]
# 이 연산은 (행을 따라) 수직적으로 데이터를 연결하고 (열을 따라) 수평으로 연결하지 않는다. 이 예에서 동일한 인덱스를 가진 행이 있다(예를 들면 3).

# %%
result_concat.loc[4]
# Out:
#       state            city        lat         lng  population
# 4        ut  salt lake city  40.755851 -111.896657         NaN
# 4  new-york        new york        NaN         NaN   8363710.0

# %% [markdown]
# 또는 인덱스를 무시하도록 설정할 수 있다.

# %%
result_concat=pd.concat([city_loc, city_pop], ignore_index=True)

# %%
result_concat
# Out:
#         state            city        lat         lng  population
# 0          ca    san francico  37.781334 -122.416728         NaN
# 1          ny        new york  40.705649  -74.008344         NaN
# 2          fl           miami  25.791100  -80.320733         NaN
# 3          oh       cleveland  41.473508  -81.739791         NaN
# 4          ut  salt lake city  40.755851 -111.896657         NaN
# 5  california    san francico        NaN         NaN    808976.0
# 6    new-york        new york        NaN         NaN   8363710.0
# 7     florida           miami        NaN         NaN    413210.0
# 8       texas         houston        NaN         NaN   2242193.0

# %% [markdown]
# 한 DataFrame에 열이 없을 때 NaN이 채워져 있는 것처럼 동작한다. join="inner"로 설정하면 양쪽의 DataFrame에 존재하는 열만 반환된다.

# %%
result_concat=pd.concat([city_loc, city_pop], ignore_index=True, join='inner')

# %%
result_concat
# Out:
#         state            city
# 0          ca    san francico
# 1          ny        new york
# 2          fl           miami
# 3          oh       cleveland
# 4          ut  salt lake city
# 5  california    san francico
# 6    new-york        new york
# 7     florida           miami
# 8       texas         houston

# %% [markdown]
# axis=1로 설정하면 DataFrame을 수직이 아니라 수평으로 연결할 수 있다.

# %%
pd.concat([city_loc, city_pop],axis=1)
# Out:
#   state            city        lat         lng  population          city  \
# 0    ca    san francico  37.781334 -122.416728         NaN           NaN
# 1    ny        new york  40.705649  -74.008344         NaN           NaN
# 2    fl           miami  25.791100  -80.320733         NaN           NaN
# 3    oh       cleveland  41.473508  -81.739791    808976.0  san francico
# 4    ut  salt lake city  40.755851 -111.896657   8363710.0      new york
# 5   NaN             NaN        NaN         NaN    413210.0         miami
# 6   NaN             NaN        NaN         NaN   2242193.0       houston
#
#         state
# 0         NaN
# 1         NaN
# 2         NaN
# 3  california
# 4    new-york
# 5     florida
# 6       texas

# %% [markdown]
# 이 경우 인덱스가 잘 정렬되지 않기 때문에 의미가 없다(예를 들어 Cleveland와 San Francisco의 인덱스 레이블이 3이기 때문에 동일한 행에 놓여 있다). 이 DataFrame을 연결하기 전에 도시로 인덱스를 재설정해 보자.

# %%
pd.concat([city_loc.set_index('city'), city_pop.set_index('city')],axis=1)
# Out:
#                state        lat         lng  population       state
# city
# san francico      ca  37.781334 -122.416728    808976.0  california
# new york          ny  40.705649  -74.008344   8363710.0    new-york
# miami             fl  25.791100  -80.320733    413210.0     florida
# cleveland         oh  41.473508  -81.739791         NaN         NaN
# salt lake city    ut  40.755851 -111.896657         NaN         NaN
# houston          NaN        NaN         NaN   2242193.0       texas

# %% [markdown]
# FULL OUTER JOIN을 수행한 것과 비슷하다. 하지만 state 열이 state_x와 state_y로 바뀌지 않았고 city 열이 인덱스가 되었다.

# %% [markdown]
# append() 메서드는 DataFrame을 수직으로 연결하는 단축 메서드이다.

# %%
city_loc.append(city_pop)
# Out:
# <ipython-input-143-b431bb1e4b1b>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   city_loc.append(city_pop)
#         state            city        lat         lng  population
# 0          ca    san francico  37.781334 -122.416728         NaN
# 1          ny        new york  40.705649  -74.008344         NaN
# 2          fl           miami  25.791100  -80.320733         NaN
# 3          oh       cleveland  41.473508  -81.739791         NaN
# 4          ut  salt lake city  40.755851 -111.896657         NaN
# 3  california    san francico        NaN         NaN    808976.0
# 4    new-york        new york        NaN         NaN   8363710.0
# 5     florida           miami        NaN         NaN    413210.0
# 6       texas         houston        NaN         NaN   2242193.0

# %% [markdown]
# 판다스의 다른 메서드와 마찬가지로 append() 메서드는 실제 city_loc을 수정하지 않는다. 복사본을 만들어 수정한 다음 반환한다.

# %% [markdown]
# ### **범주**
#
# 범주로 표현된 값을 가진 경우가 많다. 예를 들어 1은 여성, 2는 남성이거나 "A"는 좋은 것, "B"는 평균, "C"는 나쁜 것 등이다. 범주형 값을 읽기 힘들고 다루기 번거롭다. 하지만 판다스에서는 간단하다.

# %%
city_eco=city_pop.copy()
city_eco['eco_code']=[17,17,24,34]
city_eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 3 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   population  4 non-null      int64
#  1   city        4 non-null      object
#  2   state       4 non-null      object
#  3   eco_code    4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 332.0+ bytes

# %% [markdown]
# 이제 eco_code열은 의미없는 코드이다. eco_code를 기반으로 새로운 범주형 열을 만들어 보자

# %%
city_eco['economy']=city_eco['eco_code'].astype('category')
city_eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 3 to 6
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   population  4 non-null      int64
#  1   city        4 non-null      object
#  2   state       4 non-null      object
#  3   eco_code    4 non-null      int64
#  4   economy     4 non-null      category
# dtypes: category(1), int64(2), object(2)
# memory usage: 468.0+ bytes

# %% [markdown]
# 의미있는 이름을 가진 범주를 지정할 수 있다.

# %%
city_eco['economy'].cat.rename_categories=['finance','energy','tour']

# %%
city_eco
# Out:
#    population          city       state  eco_code economy
# 3      808976  san francico  california        17      17
# 4     8363710      new york    new-york        17      17
# 5      413210         miami     florida        24      24
# 6     2242193       houston       texas        34      34

# %% [markdown]
# 범주형 값은 알파벳 순서가 아니라 범주형 순서로 정렬한다.
